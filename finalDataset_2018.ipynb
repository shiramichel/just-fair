# %%
import pandas as pd

# %%
fd = pd.read_csv('FinalDataset.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (100,152,162,181,201,206,211,216,221,223,240,252,257,264,269,276,279,281,288,291,293,329,334,335,336,337,338,339,340,341,342,343,344,345,346,347,356,357,358,362,363,367,368,369,370,371,372,373,374,375,378,379,380,381,382,383,384,385,386,387,388,389,390,395,396,397,398,399,400,401,402,405,406,407,408,409,410,411,412,413,414,415,416,417,422,423,424,533,534,535,536,537,538,540,541,542,543,544,546,547,549,550,552,553) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ds = fd[fd['SENTYR'] == 2018]
ds
# Out:
#         CIRCDIST          CASLGKY  SAFETY ZONE  AMTFINEC   AMTREST  AMTTOTAL  \
# 89             1  009011700084CR0     NaN    D       0.0  828217.0  828217.0
# 90             1  009011700103CR0     NaN    D       0.0       0.0       0.0
# 91             1  009011700209CR0     NaN    D       0.0       0.0       0.0
# 92             1  009011800003CR0     NaN  NaN       0.0       0.0       0.0
# 93             1  009011800012CR0     NaN    D       0.0       0.0       0.0
# ...          ...              ...     ...  ...       ...       ...       ...
# 595821        94  113J51700003CR0     0.0    D       0.0       0.0       0.0
# 595822        94  113J51700003CR0     0.0    D       0.0       0.0       0.0
# 595823        94  113J51700003CR0     1.0    D       0.0       0.0       0.0
# 595824        94  113J51700003CR0     1.0    D       0.0       0.0       0.0
# 595825        94  113J51700003CR0     1.0    D       0.0       0.0       0.0
#
# ...

# %%
ds.to_csv('finalDs_2018.csv', index=False)
