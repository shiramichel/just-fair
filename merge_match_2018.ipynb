# %%
import pandas as pd
import numpy as np
from dfply import *

# %%
fjc = pd.read_csv('FJC_2018.csv')
ussc = pd.read_csv('ussc_2018_clean.csv')
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/3724029126.py:1: DtypeWarning: Columns (4,11,42,54,65,96,108,113,120,125,151,152,153,154,155,156,157,159) have mixed types. Specify dtype option on import or set low_memory=False.
#   fjc = pd.read_csv('FJC_2018.csv')

# %%
fjc_new = fjc[['ID','SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT', 'FJDcode1', 'FJDcode2', 'FJDcode3', 'FJDcode4', 'FJDcode5', 'FJDcode6', 'FJDcode7', 'FJDcode8', 'FJDcode9', 'FJDcode10']]

# %%
ussc_new = ussc[['CIRCDIST', 'SENTMON', 'SENTYR', 'SENTTOT_new', 'FINE', 'PROBATN', 'USSCIDN', 'floorSENTTOT', 'roundSENTTOT','USSCcode1', 'USSCcode2', 'USSCcode3', 'USSCcode4', 'USSCcode5']]

# %%
ussc_new = ussc_new.rename({'CIRCDIST': 'DISTRICT', 'SENTTOT_new': 'PRISTOT', 'FINE': 'FINETOT', 'PROBATN': 'PROBTOT'}, axis=1)

# %%
fjc_new.replace(-8, 'NA', inplace=True)
fjc_new.replace('-8', 'NA', inplace=True)
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/1800276897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fjc_new.replace(-8, 'NA', inplace=True)
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/1800276897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fjc_new.replace('-8', 'NA', inplace=True)

# %%
fjc_new = fjc_new

# %%
fcj_ussc = pd.merge(fjc_new, ussc_new, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fcj_ussc
# Out:
#             ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366204        9    2018        90     42.0        0        0
# 1      4366322        7    2018        90     60.0        0        0
# 2      4366322        7    2018        90     60.0        0        0
# 3      4366344        7    2018        90     60.0        0        0
# 4      4366344        7    2018        90     60.0        0        0
# ...        ...      ...     ...       ...      ...      ...      ...
# 26859  4580022        9    2018        34     60.0        0        0
# 26860  4580022        9    2018        34     60.0        0        0
# 26861  4580022        9    2018        34     60.0        0        0
# 26862  4580022        9    2018        34     60.0        0        0
# 26863  4580022        9    2018        34     60.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10  USSCIDN  \
# 0        181957   181344   181014  ...   181344    181014  2488790
# ...

# %%
fcj_ussc = fcj_ussc.drop_duplicates()
fcj_ussc
# Out:
#             ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366204        9    2018        90     42.0        0        0
# 1      4366322        7    2018        90     60.0        0        0
# 2      4366322        7    2018        90     60.0        0        0
# 3      4366344        7    2018        90     60.0        0        0
# 4      4366344        7    2018        90     60.0        0        0
# ...        ...      ...     ...       ...      ...      ...      ...
# 26859  4580022        9    2018        34     60.0        0        0
# 26860  4580022        9    2018        34     60.0        0        0
# 26861  4580022        9    2018        34     60.0        0        0
# 26862  4580022        9    2018        34     60.0        0        0
# 26863  4580022        9    2018        34     60.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10  USSCIDN  \
# 0        181957   181344   181014  ...   181344    181014  2488790
# ...

# %%
matched = []
no_match = []

for i in range(len(fcj_ussc)):
    for j in range(len(fcj_ussc)):
        if fcj_ussc.iloc[i,7] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,7] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,7] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,7] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,7] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,8] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,8] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,8] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,8] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,8] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,9] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,9] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,9] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,9] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,9] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,10] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,10] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,10] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,10] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,10] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,11] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,11] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,11] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,11] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,11] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,12] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,12] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,12] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,12] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,12] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,13] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,13] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,13] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,13] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,13] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,14] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,14] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,14] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,14] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,14] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,15] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,15] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,15] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,15] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,15] == fcj_ussc.iloc[j,24] or fcj_ussc.iloc[i,16] == fcj_ussc.iloc[j,20] or fcj_ussc.iloc[i,16] == fcj_ussc.iloc[j,21] or fcj_ussc.iloc[i,16] == fcj_ussc.iloc[j,22] or fcj_ussc.iloc[i,16] == fcj_ussc.iloc[j,23] or fcj_ussc.iloc[i,16] == fcj_ussc.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
matched_1 = fcj_ussc.iloc[matched,:]
matched_1.reset_index()
# Out:
#       index       ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0         3  4366344        7    2018        90     60.0        0        0
# 1         4  4366344        7    2018        90     60.0        0        0
# 2         5  4366355        1    2018        90     18.0        0        0
# 3         7  4366380        1    2018        90    180.0        0        0
# 4         8  4366389        1    2018        90     78.0        0        0
# ...     ...      ...      ...     ...       ...      ...      ...      ...
# 9653  26859  4580022        9    2018        34     60.0        0        0
# 9654  26860  4580022        9    2018        34     60.0        0        0
# 9655  26861  4580022        9    2018        34     60.0        0        0
# 9656  26862  4580022        9    2018        34     60.0        0        0
# 9657  26863  4580022        9    2018        34     60.0        0        0
#
# ...

# %%
unmatched = pd.merge(fjc_new, ussc_new, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90  9996.00        0        0
# 1       4365583.0        5    2018        90  9996.00        0        0
# 2       4365752.0        6    2018        90    86.00       36        0
# 3       4365799.0        2    2018        90   144.00        0        0
# 4       4366018.0        4    2018        90     0.00        0        0
# ...           ...      ...     ...       ...      ...      ...      ...
# 129433        NaN        8    2018        91    82.00        0        0
# 129434        NaN        9    2018        68    14.95        0        0
# 129435        NaN        8    2018        91   240.00        0        0
# 129436        NaN        3    2018        65     0.10        0        0
# 129437        NaN        5    2018        10    70.00        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched = unmatched.append(fcj_ussc.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/1547002470.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched = unmatched.append(fcj_ussc.iloc[no_match,:])

# %%
unmatched = unmatched.drop_duplicates()
unmatched
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90  9996.00        0        0
# 1       4365583.0        5    2018        90  9996.00        0        0
# 2       4365752.0        6    2018        90    86.00       36        0
# 3       4365799.0        2    2018        90   144.00        0        0
# 4       4366018.0        4    2018        90     0.00        0        0
# ...           ...      ...     ...       ...      ...      ...      ...
# 129433        NaN        8    2018        91    82.00        0        0
# 129434        NaN        9    2018        68    14.95        0        0
# 129435        NaN        8    2018        91   240.00        0        0
# 129436        NaN        3    2018        65     0.10        0        0
# 129437        NaN        5    2018        10    70.00        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched_fjc = (unmatched >>
mask(unmatched.USSCIDN.isna()) >>
drop(unmatched.floorSENTTOT, unmatched.roundSENTTOT, unmatched.USSCIDN, unmatched.USSCcode1, unmatched.USSCcode2, unmatched.USSCcode3, unmatched.USSCcode4, unmatched.USSCcode5)
)
unmatched_fjc
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4365582.0        2    2018        90   9996.0        0        0
# 1      4365583.0        5    2018        90   9996.0        0        0
# 2      4365752.0        6    2018        90     86.0       36        0
# 3      4365799.0        2    2018        90    144.0        0        0
# 4      4366018.0        4    2018        90      0.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 88127  4807436.0       10    2018        34    125.0        0        0
# 88128  4807442.0       11    2018        34     68.0        0        0
# 88129  4807451.0       12    2018        34    180.0        0        0
# 88130  4807452.0       12    2018        34      2.0        0        0
# 88131  4807515.0       11    2018        34     18.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3 FJDcode4 FJDcode5 FJDcode6 FJDcode7  \
# ...

# %%
unmatched_ussc = (unmatched >>
mask(unmatched.USSCIDN.notna()) >>
drop(unmatched.ID, unmatched.FJDcode1, unmatched.FJDcode2, unmatched.FJDcode3, unmatched.FJDcode4, unmatched.FJDcode5, unmatched.FJDcode5, unmatched.FJDcode6, unmatched.FJDcode7, unmatched.FJDcode8, unmatched.FJDcode9, unmatched.FJDcode10)
)
unmatched_ussc
# Out:
#         SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 15            9    2018        90    42.00        0        0  2488790.0
# 33            7    2018        90    60.00        0        0  2478769.0
# 34            7    2018        90    60.00        0        0  2482515.0
# 35            7    2018        90    60.00        0        0  2478769.0
# 36            7    2018        90    60.00        0        0  2482515.0
# ...         ...     ...       ...      ...      ...      ...        ...
# 129433        8    2018        91    82.00        0        0  2515497.0
# 129434        9    2018        68    14.95        0        0  2515502.0
# 129435        8    2018        91   240.00        0        0  2515560.0
# 129436        3    2018        65     0.10        0        0  2515569.0
# 129437        5    2018        10    70.00        0        0  2519665.0
#
#         floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  \
# ...

# %%
unmatched_ussc['PRISTOT'] = unmatched_ussc['roundSENTTOT']
unmatched_ussc
# Out:
#         SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 15            9    2018        90     42.0        0        0  2488790.0
# 33            7    2018        90     60.0        0        0  2478769.0
# 34            7    2018        90     60.0        0        0  2482515.0
# 35            7    2018        90     60.0        0        0  2478769.0
# 36            7    2018        90     60.0        0        0  2482515.0
# ...         ...     ...       ...      ...      ...      ...        ...
# 129433        8    2018        91     82.0        0        0  2515497.0
# 129434        9    2018        68     15.0        0        0  2515502.0
# 129435        8    2018        91    240.0        0        0  2515560.0
# 129436        3    2018        65      0.0        0        0  2515569.0
# 129437        5    2018        10     70.0        0        0  2519665.0
#
#         floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  \
# ...

# %%
fcj_ussc_2 = pd.merge(unmatched_fjc, unmatched_ussc, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fcj_ussc_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366018.0        4    2018        90      0.0        0        0
# 1      4366018.0        4    2018        90      0.0        0        0
# 2      4366265.0        4    2018        90      0.0        0        0
# 3      4366265.0        4    2018        90      0.0        0        0
# 4      4366329.0        4    2018        90      0.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23428  4580028.0        7    2018        34     12.0        0        0
# 23429  4580028.0        7    2018        34     12.0        0        0
# 23430  4580037.0        4    2018        34      7.0        0        0
# 23431  4580037.0        4    2018        34      7.0        0        0
# 23432  4580079.0        2    2018        34      8.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched = []
no_match = []

for i in range(len(fcj_ussc_2)):
    for j in range(len(fcj_ussc_2)):
        if fcj_ussc_2.iloc[i,7] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,7] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,7] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,7] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,7] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,8] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,8] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,8] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,8] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,8] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,9] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,9] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,9] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,9] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,9] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,10] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,10] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,10] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,10] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,10] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,11] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,11] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,11] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,11] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,11] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,12] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,12] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,12] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,12] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,12] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,13] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,13] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,13] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,13] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,13] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,14] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,14] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,14] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,14] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,14] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,15] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,15] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,15] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,15] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,15] == fcj_ussc_2.iloc[j,24] or fcj_ussc_2.iloc[i,16] == fcj_ussc_2.iloc[j,20] or fcj_ussc_2.iloc[i,16] == fcj_ussc_2.iloc[j,21] or fcj_ussc_2.iloc[i,16] == fcj_ussc_2.iloc[j,22] or fcj_ussc_2.iloc[i,16] == fcj_ussc_2.iloc[j,23] or fcj_ussc_2.iloc[i,16] == fcj_ussc_2.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
unmatched_2 = pd.merge(unmatched_fjc, unmatched_ussc, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched_2
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90   9996.0        0        0
# 1       4365583.0        5    2018        90   9996.0        0        0
# 2       4365752.0        6    2018        90     86.0       36        0
# 3       4365799.0        2    2018        90    144.0        0        0
# 4       4366018.0        4    2018        90      0.0        0        0
# ...           ...      ...     ...       ...      ...      ...      ...
# 142893        NaN        7    2018        18     19.0     1000        0
# 142894        NaN        9    2018        44      0.0      350        0
# 142895        NaN        8    2018        91     82.0        0        0
# 142896        NaN        8    2018        91    240.0        0        0
# 142897        NaN        5    2018        10     70.0        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2 = fcj_ussc_2.iloc[matched,:]
matched_2.reset_index()

unmatched_2 = unmatched_2.append(fcj_ussc_2.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/136010796.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched_2 = unmatched_2.append(fcj_ussc_2.iloc[no_match,:])

# %%
unmatched_fjc_2 = (unmatched_2 >>
mask(unmatched_2.USSCIDN.isna()) >>
drop(unmatched_2.floorSENTTOT, unmatched_2.roundSENTTOT, unmatched_2.USSCIDN, unmatched_2.USSCcode1, unmatched_2.USSCcode2, unmatched_2.USSCcode3, unmatched_2.USSCcode4, unmatched_2.USSCcode5)
)
unmatched_fjc_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4365582.0        2    2018        90   9996.0        0        0
# 1      4365583.0        5    2018        90   9996.0        0        0
# 2      4365752.0        6    2018        90     86.0       36        0
# 3      4365799.0        2    2018        90    144.0        0        0
# 24     4366103.0        6    2018        90      0.0        0       60
# ...          ...      ...     ...       ...      ...      ...      ...
# 77410  4807436.0       10    2018        34    125.0        0        0
# 77411  4807442.0       11    2018        34     68.0        0        0
# 77412  4807451.0       12    2018        34    180.0        0        0
# 77413  4807452.0       12    2018        34      2.0        0        0
# 77414  4807515.0       11    2018        34     18.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3 FJDcode4 FJDcode5 FJDcode6 FJDcode7  \
# ...

# %%
unmatched_ussc_2 = (unmatched_2 >>
mask(unmatched_2.USSCIDN.notna()) >>
drop(unmatched_2.ID, unmatched_2.FJDcode1, unmatched_2.FJDcode2, unmatched_2.FJDcode3, unmatched_2.FJDcode4, unmatched_2.FJDcode5, unmatched_2.FJDcode5, unmatched_2.FJDcode6, unmatched_2.FJDcode7, unmatched_2.FJDcode8, unmatched_2.FJDcode9, unmatched_2.FJDcode10)
)
unmatched_ussc_2
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 4            4    2018        90      0.0        0        0  2460083.0
# 5            4    2018        90      0.0        0        0  2461003.0
# 6            4    2018        90      0.0        0        0  2460083.0
# 7            4    2018        90      0.0        0        0  2461003.0
# 8            4    2018        90      0.0        0        0  2460083.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 23428        7    2018        34     12.0        0        0  2478495.0
# 23429        7    2018        34     12.0        0        0  2511256.0
# 23430        4    2018        34      7.0        0        0  2458187.0
# 23431        4    2018        34      7.0        0        0  2460323.0
# 23432        2    2018        34      8.0        0        0  2447299.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
unmatched_ussc_2['PRISTOT'] = unmatched_ussc_2['floorSENTTOT']
unmatched_ussc_2
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 4            4    2018        90      0.0        0        0  2460083.0
# 5            4    2018        90      0.0        0        0  2461003.0
# 6            4    2018        90      0.0        0        0  2460083.0
# 7            4    2018        90      0.0        0        0  2461003.0
# 8            4    2018        90      0.0        0        0  2460083.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 23428        7    2018        34     12.0        0        0  2478495.0
# 23429        7    2018        34     12.0        0        0  2511256.0
# 23430        4    2018        34      6.0        0        0  2458187.0
# 23431        4    2018        34      7.0        0        0  2460323.0
# 23432        2    2018        34      7.0        0        0  2447299.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
fcj_ussc_3 = pd.merge(unmatched_fjc_2, unmatched_ussc_2, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fcj_ussc_3
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0     4385027.0        8    2018         8      6.0        0        0
# 1     4385994.0        8    2018         8      6.0        0        0
# 2     4385052.0        4    2018         8      1.0        0        0
# 3     4385447.0        4    2018         8      1.0        0        0
# 4     4391108.0        1    2018         9      6.0        0        0
# ...         ...      ...     ...       ...      ...      ...      ...
# 2656  4569019.0        2    2018        31      7.0        0        0
# 2657  4573815.0        2    2018        31      7.0        0        0
# 2658  4573815.0        2    2018        31      7.0        0        0
# 2659  4578809.0        4    2018        34      6.0        0        0
# 2660  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched = []
no_match = []

for i in range(len(fcj_ussc_3)):
    for j in range(len(fcj_ussc_3)):
        if fcj_ussc_3.iloc[i,7] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,7] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,7] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,7] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,7] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,8] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,8] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,8] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,8] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,8] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,9] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,9] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,9] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,9] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,9] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,10] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,10] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,10] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,10] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,10] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,11] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,11] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,11] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,11] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,11] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,12] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,12] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,12] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,12] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,12] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,13] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,13] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,13] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,13] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,13] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,14] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,14] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,14] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,14] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,14] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,15] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,15] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,15] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,15] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,15] == fcj_ussc_3.iloc[j,24] or fcj_ussc_3.iloc[i,16] == fcj_ussc_3.iloc[j,20] or fcj_ussc_3.iloc[i,16] == fcj_ussc_3.iloc[j,21] or fcj_ussc_3.iloc[i,16] == fcj_ussc_3.iloc[j,22] or fcj_ussc_3.iloc[i,16] == fcj_ussc_3.iloc[j,23] or fcj_ussc_3.iloc[i,16] == fcj_ussc_3.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
unmatched_3 = pd.merge(unmatched_fjc_2, unmatched_ussc_2, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched_3
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90   9996.0        0        0
# 1       4365583.0        5    2018        90   9996.0        0        0
# 2       4365752.0        6    2018        90     86.0       36        0
# 3       4365799.0        2    2018        90    144.0        0        0
# 4       4366103.0        6    2018        90      0.0        0       60
# ...           ...      ...     ...       ...      ...      ...      ...
# 165060        NaN        7    2018        18     19.0     1000        0
# 165061        NaN        9    2018        44      0.0      350        0
# 165062        NaN        8    2018        91     82.0        0        0
# 165063        NaN        8    2018        91    240.0        0        0
# 165064        NaN        5    2018        10     70.0        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_3 = fcj_ussc_3.iloc[matched,:]
matched_3.reset_index()

unmatched_3 = unmatched_3.append(fcj_ussc_3.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_25463/1680099784.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched_3 = unmatched_3.append(fcj_ussc_3.iloc[no_match,:])

# %%
matched_2018 = pd.concat([matched_1, matched_2, matched_3], axis=0)
matched_2018
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 3      4366344.0        7    2018        90     60.0        0        0
# 4      4366344.0        7    2018        90     60.0        0        0
# 5      4366355.0        1    2018        90     18.0        0        0
# 7      4366380.0        1    2018        90    180.0        0        0
# 8      4366389.0        1    2018        90     78.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23394  4578937.0        5    2018        34      0.0        0        0
# 23395  4578937.0        5    2018        34      0.0        0        0
# 23396  4578937.0        5    2018        34      0.0        0        0
# 2292   4535508.0        9    2018        78      0.0        0        0
# 2293   4535512.0        9    2018        78      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2018.drop_duplicates(subset=['USSCIDN', 'ID'])
matched_2018
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 3      4366344.0        7    2018        90     60.0        0        0
# 4      4366344.0        7    2018        90     60.0        0        0
# 5      4366355.0        1    2018        90     18.0        0        0
# 7      4366380.0        1    2018        90    180.0        0        0
# 8      4366389.0        1    2018        90     78.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23394  4578937.0        5    2018        34      0.0        0        0
# 23395  4578937.0        5    2018        34      0.0        0        0
# 23396  4578937.0        5    2018        34      0.0        0        0
# 2292   4535508.0        9    2018        78      0.0        0        0
# 2293   4535512.0        9    2018        78      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2018.to_csv('matched_2018.csv', index=False)

# %%
unmatched_2018 = pd.concat([unmatched, unmatched_2, unmatched_3], axis=0)
unmatched_2018
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0     4365582.0        2    2018        90   9996.0        0        0
# 1     4365583.0        5    2018        90   9996.0        0        0
# 2     4365752.0        6    2018        90     86.0       36        0
# 3     4365799.0        2    2018        90    144.0        0        0
# 4     4366018.0        4    2018        90      0.0        0        0
# ...         ...      ...     ...       ...      ...      ...      ...
# 2656  4569019.0        2    2018        31      7.0        0        0
# 2657  4573815.0        2    2018        31      7.0        0        0
# 2658  4573815.0        2    2018        31      7.0        0        0
# 2659  4578809.0        4    2018        34      6.0        0        0
# 2660  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched_2018.drop_duplicates(subset=['USSCIDN', 'ID'])
unmatched_2018
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0     4365582.0        2    2018        90   9996.0        0        0
# 1     4365583.0        5    2018        90   9996.0        0        0
# 2     4365752.0        6    2018        90     86.0       36        0
# 3     4365799.0        2    2018        90    144.0        0        0
# 4     4366018.0        4    2018        90      0.0        0        0
# ...         ...      ...     ...       ...      ...      ...      ...
# 2656  4569019.0        2    2018        31      7.0        0        0
# 2657  4573815.0        2    2018        31      7.0        0        0
# 2658  4573815.0        2    2018        31      7.0        0        0
# 2659  4578809.0        4    2018        34      6.0        0        0
# 2660  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched_2018.to_csv('unmatched_2018.csv', index=False)
