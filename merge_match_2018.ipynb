# %%
import pandas as pd
import numpy as np
from dfply import *

# %%
fjc = pd.read_csv('FJC_2018.csv')
ussc = pd.read_csv('ussc_2018_clean.csv')
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9777/3724029126.py:1: DtypeWarning: Columns (4,11,42,54,65,96,108,113,120,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   fjc = pd.read_csv('FJC_2018.csv')

# %%
ussc.shape
# Out:
# (53215, 164)

# %%
fjc_new = fjc[['ID','SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT', 'FJDcode1', 'FJDcode2', 'FJDcode3', 'FJDcode4', 'FJDcode5', 'FJDcode6', 'FJDcode7', 'FJDcode8', 'FJDcode9', 'FJDcode10']]

# %%
ussc_new = ussc[['CIRCDIST', 'SENTMON', 'SENTYR', 'SENTTOT_new', 'FINE', 'PROBATN', 'USSCIDN', 'floorSENTTOT', 'roundSENTTOT','USSCcode1', 'USSCcode2', 'USSCcode3', 'USSCcode4', 'USSCcode5']]

# %%
ussc_new = ussc_new.rename({'CIRCDIST': 'DISTRICT', 'SENTTOT_new': 'PRISTOT', 'FINE': 'FINETOT', 'PROBATN': 'PROBTOT'}, axis=1)

# %%
fjc_new.replace(-8, 'NA', inplace=True)
fjc_new.replace('-8', 'NA', inplace=True)
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9777/1800276897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fjc_new.replace(-8, 'NA', inplace=True)
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9777/1800276897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fjc_new.replace('-8', 'NA', inplace=True)

# %%
fjc_new = fjc_new

# %%
fjc_ussc = pd.merge(fjc_new, ussc_new, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fjc_ussc
# Out:
#             ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366204        9    2018        90     42.0        0        0
# 1      4366322        7    2018        90     60.0        0        0
# 2      4366322        7    2018        90     60.0        0        0
# 3      4366344        7    2018        90     60.0        0        0
# 4      4366344        7    2018        90     60.0        0        0
# ...        ...      ...     ...       ...      ...      ...      ...
# 26859  4580022        9    2018        34     60.0        0        0
# 26860  4580022        9    2018        34     60.0        0        0
# 26861  4580022        9    2018        34     60.0        0        0
# 26862  4580022        9    2018        34     60.0        0        0
# 26863  4580022        9    2018        34     60.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10  USSCIDN  \
# 0        181957   181344   181014  ...   181344    181014  2488790
# ...

# %%
dup_id = fjc_ussc.loc[fjc_ussc.duplicated(subset='ID', keep='last')]
dup_idn = fjc_ussc.loc[fjc_ussc.duplicated(subset='USSCIDN', keep='last')]
dup = pd.concat([dup_id, dup_idn], axis=0)
dup
# Out:
#             ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 1      4366322        7    2018        90     60.0        0        0
# 3      4366344        7    2018        90     60.0        0        0
# 8      4366389        1    2018        90     78.0        0        0
# 13     4366429        2    2018        90      0.0        0       36
# 15     4366620        2    2018        90      0.0        0       36
# ...        ...      ...     ...       ...      ...      ...      ...
# 26784  4579693        8    2018        34    151.0        0        0
# 26785  4579693        8    2018        34    151.0        0        0
# 26804  4579970        1    2018        34     37.0        0        0
# 26805  4579970        1    2018        34     37.0        0        0
# 26808  4579971        2    2018        34     72.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10  USSCIDN  \
# 1         18922       NA       NA  ...       NA        NA  2478769
# ...

# %%
fjc_ussc = fjc_ussc.drop_duplicates(subset=['ID'], keep='first')
fjc_ussc = fjc_ussc.drop_duplicates(subset='USSCIDN', keep='first')
fjc_ussc
# Out:
#             ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366204        9    2018        90     42.0        0        0
# 1      4366322        7    2018        90     60.0        0        0
# 5      4366355        1    2018        90     18.0        0        0
# 7      4366380        1    2018        90    180.0        0        0
# 8      4366389        1    2018        90     78.0        0        0
# ...        ...      ...     ...       ...      ...      ...      ...
# 26843  4580010        2    2018        34     46.0        0        0
# 26846  4580011        6    2018        34    120.0        0        0
# 26849  4580017        5    2018        34     12.0        0        0
# 26851  4580018        6    2018        34     60.0        0        0
# 26854  4580022        9    2018        34     60.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10  USSCIDN  \
# 0        181957   181344   181014  ...   181344    181014  2488790
# ...

# %%
matched = []
no_match = []

for i in range(len(fjc_ussc)):
    for j in range(len(fjc_ussc)):
        if fjc_ussc.iloc[i,7] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,7] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,7] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,7] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,7] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,8] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,8] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,8] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,8] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,8] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,9] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,9] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,9] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,9] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,9] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,10] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,10] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,10] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,10] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,10] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,11] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,11] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,11] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,11] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,11] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,12] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,12] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,12] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,12] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,12] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,13] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,13] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,13] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,13] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,13] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,14] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,14] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,14] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,14] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,14] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,15] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,15] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,15] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,15] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,15] == fjc_ussc.iloc[j,24] or fjc_ussc.iloc[i,16] == fjc_ussc.iloc[j,20] or fjc_ussc.iloc[i,16] == fjc_ussc.iloc[j,21] or fjc_ussc.iloc[i,16] == fjc_ussc.iloc[j,22] or fjc_ussc.iloc[i,16] == fjc_ussc.iloc[j,23] or fjc_ussc.iloc[i,16] == fjc_ussc.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
matched_1 = fjc_ussc.iloc[matched,:]
matched_1.reset_index()
# Out:
#       index       ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0         5  4366355        1    2018        90     18.0        0        0
# 1         7  4366380        1    2018        90    180.0        0        0
# 2         8  4366389        1    2018        90     78.0        0        0
# 3        10  4366406        4    2018        90     60.0        0        0
# 4        13  4366429        2    2018        90      0.0        0       36
# ...     ...      ...      ...     ...       ...      ...      ...      ...
# 2398  26843  4580010        2    2018        34     46.0        0        0
# 2399  26846  4580011        6    2018        34    120.0        0        0
# 2400  26849  4580017        5    2018        34     12.0        0        0
# 2401  26851  4580018        6    2018        34     60.0        0        0
# 2402  26854  4580022        9    2018        34     60.0        0        0
#
# ...

# %%
unmatched = pd.merge(fjc_new, ussc_new, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90  9996.00        0        0
# 1       4365583.0        5    2018        90  9996.00        0        0
# 2       4365752.0        6    2018        90    86.00       36        0
# 3       4365799.0        2    2018        90   144.00        0        0
# 4       4366018.0        4    2018        90     0.00        0        0
# ...           ...      ...     ...       ...      ...      ...      ...
# 129433        NaN        8    2018        91    82.00        0        0
# 129434        NaN        9    2018        68    14.95        0        0
# 129435        NaN        8    2018        91   240.00        0        0
# 129436        NaN        3    2018        65     0.10        0        0
# 129437        NaN        5    2018        10    70.00        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched = unmatched.append(fjc_ussc.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9777/3694392881.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched = unmatched.append(fjc_ussc.iloc[no_match,:])

# %%
unmatched_fjc = (unmatched >>
mask(unmatched.USSCIDN.isna()) >>
drop(unmatched.floorSENTTOT, unmatched.roundSENTTOT, unmatched.USSCIDN, unmatched.USSCcode1, unmatched.USSCcode2, unmatched.USSCcode3, unmatched.USSCcode4, unmatched.USSCcode5)
)
unmatched_fjc
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4365582.0        2    2018        90   9996.0        0        0
# 1      4365583.0        5    2018        90   9996.0        0        0
# 2      4365752.0        6    2018        90     86.0       36        0
# 3      4365799.0        2    2018        90    144.0        0        0
# 4      4366018.0        4    2018        90      0.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 88127  4807436.0       10    2018        34    125.0        0        0
# 88128  4807442.0       11    2018        34     68.0        0        0
# 88129  4807451.0       12    2018        34    180.0        0        0
# 88130  4807452.0       12    2018        34      2.0        0        0
# 88131  4807515.0       11    2018        34     18.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3 FJDcode4 FJDcode5  FJDcode6 FJDcode7  \
# ...

# %%
unmatched_ussc = (unmatched >>
mask(unmatched.USSCIDN.notna()) >>
drop(unmatched.ID, unmatched.FJDcode1, unmatched.FJDcode2, unmatched.FJDcode3, unmatched.FJDcode4, unmatched.FJDcode5, unmatched.FJDcode5, unmatched.FJDcode6, unmatched.FJDcode7, unmatched.FJDcode8, unmatched.FJDcode9, unmatched.FJDcode10)
)
unmatched_ussc
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 15           9    2018        90     42.0        0        0  2488790.0
# 33           7    2018        90     60.0        0        0  2478769.0
# 34           7    2018        90     60.0        0        0  2482515.0
# 35           7    2018        90     60.0        0        0  2478769.0
# 36           7    2018        90     60.0        0        0  2482515.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 26802        7    2018        34     28.0        0        0  2479209.0
# 26803        7    2018        34     84.0        0        0  2479021.0
# 26804        1    2018        34     37.0        0        0  2442414.0
# 26838        2    2018        34     18.0        0        0  2446906.0
# 26840        3    2018        34     21.0        0        0  2455959.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
unmatched_ussc['PRISTOT'] = unmatched_ussc['roundSENTTOT']
unmatched_ussc
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 15           9    2018        90     42.0        0        0  2488790.0
# 33           7    2018        90     60.0        0        0  2478769.0
# 34           7    2018        90     60.0        0        0  2482515.0
# 35           7    2018        90     60.0        0        0  2478769.0
# 36           7    2018        90     60.0        0        0  2482515.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 26802        7    2018        34     28.0        0        0  2479209.0
# 26803        7    2018        34     84.0        0        0  2479021.0
# 26804        1    2018        34     37.0        0        0  2442414.0
# 26838        2    2018        34     18.0        0        0  2446906.0
# 26840        3    2018        34     21.0        0        0  2455959.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
fjc_ussc_2 = pd.merge(unmatched_fjc, unmatched_ussc, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fjc_ussc_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366018.0        4    2018        90      0.0        0        0
# 1      4366018.0        4    2018        90      0.0        0        0
# 2      4366265.0        4    2018        90      0.0        0        0
# 3      4366265.0        4    2018        90      0.0        0        0
# 4      4366329.0        4    2018        90      0.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23429  4580028.0        7    2018        34     12.0        0        0
# 23430  4580028.0        7    2018        34     12.0        0        0
# 23431  4580037.0        4    2018        34      7.0        0        0
# 23432  4580037.0        4    2018        34      7.0        0        0
# 23433  4580079.0        2    2018        34      8.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
dup_id_2 = fjc_ussc_2.loc[fjc_ussc_2.duplicated(subset='ID', keep='last')]
dup_idn_2 = fjc_ussc_2.loc[fjc_ussc_2.duplicated(subset='USSCIDN', keep='last')]
dup_2 = pd.concat([dup_id_2, dup_idn_2], axis=0)
dup_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366018.0        4    2018        90      0.0        0        0
# 2      4366265.0        4    2018        90      0.0        0        0
# 4      4366329.0        4    2018        90      0.0        0        0
# 6      4366527.0        4    2018        90      0.0        0        0
# 8      4366767.0        4    2018        90      0.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23420  4579824.0        9    2018        34      0.0        0        0
# 23421  4579841.0        9    2018        34      0.0        0        0
# 23423  4579021.0        7    2018        34      0.0        0        0
# 23424  4579022.0        7    2018        34      0.0        0        0
# 23425  4579023.0        7    2018        34      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
fjc_ussc_2 = fjc_ussc_2.drop_duplicates(subset='ID', keep='first')
fjc_ussc_2 = fjc_ussc_2.drop_duplicates(subset='USSCIDN', keep='first')
fjc_ussc_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4366018.0        4    2018        90      0.0        0        0
# 10     4366037.0        8    2018        90      0.0        0        0
# 20     4366537.0        9    2018        90      0.0        0        0
# 22     4366596.0        8    2018        90     10.0        0        0
# 23     4366598.0        9    2018        90      1.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23416  4579012.0        9    2018        34      0.0        0        0
# 23423  4579021.0        7    2018        34      0.0        0        0
# 23427  4580028.0        7    2018        34     12.0        0        0
# 23431  4580037.0        4    2018        34      7.0        0        0
# 23433  4580079.0        2    2018        34      8.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched = []
no_match = []

for i in range(len(fjc_ussc_2)):
    for j in range(len(fjc_ussc_2)):
        if fjc_ussc_2.iloc[i,7] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,7] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,7] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,7] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,7] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,8] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,8] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,8] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,8] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,8] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,9] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,9] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,9] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,9] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,9] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,10] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,10] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,10] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,10] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,10] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,11] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,11] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,11] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,11] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,11] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,12] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,12] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,12] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,12] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,12] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,13] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,13] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,13] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,13] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,13] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,14] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,14] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,14] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,14] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,14] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,15] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,15] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,15] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,15] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,15] == fjc_ussc_2.iloc[j,24] or fjc_ussc_2.iloc[i,16] == fjc_ussc_2.iloc[j,20] or fjc_ussc_2.iloc[i,16] == fjc_ussc_2.iloc[j,21] or fjc_ussc_2.iloc[i,16] == fjc_ussc_2.iloc[j,22] or fjc_ussc_2.iloc[i,16] == fjc_ussc_2.iloc[j,23] or fjc_ussc_2.iloc[i,16] == fjc_ussc_2.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
unmatched_2 = pd.merge(unmatched_fjc, unmatched_ussc, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched_2
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90   9996.0        0        0
# 1       4365583.0        5    2018        90   9996.0        0        0
# 2       4365752.0        6    2018        90     86.0       36        0
# 3       4365799.0        2    2018        90    144.0        0        0
# 4       4366018.0        4    2018        90      0.0        0        0
# ...           ...      ...     ...       ...      ...      ...      ...
# 146069        NaN        7    2018        18     19.0     1000        0
# 146070        NaN        9    2018        44      0.0      350        0
# 146071        NaN        8    2018        91     82.0        0        0
# 146072        NaN        8    2018        91    240.0        0        0
# 146073        NaN        5    2018        10     70.0        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2 = fjc_ussc_2.iloc[matched,:]
matched_2.reset_index()

unmatched_2 = unmatched_2.append(fjc_ussc_2.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9777/2849374613.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched_2 = unmatched_2.append(fjc_ussc_2.iloc[no_match,:])

# %%
unmatched_fjc_2 = (unmatched_2 >>
mask(unmatched_2.USSCIDN.isna()) >>
drop(unmatched_2.floorSENTTOT, unmatched_2.roundSENTTOT, unmatched_2.USSCIDN, unmatched_2.USSCcode1, unmatched_2.USSCcode2, unmatched_2.USSCcode3, unmatched_2.USSCcode4, unmatched_2.USSCcode5)
)
unmatched_fjc_2
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0      4365582.0        2    2018        90   9996.0        0        0
# 1      4365583.0        5    2018        90   9996.0        0        0
# 2      4365752.0        6    2018        90     86.0       36        0
# 3      4365799.0        2    2018        90    144.0        0        0
# 24     4366103.0        6    2018        90      0.0        0       60
# ...          ...      ...     ...       ...      ...      ...      ...
# 77411  4807436.0       10    2018        34    125.0        0        0
# 77412  4807442.0       11    2018        34     68.0        0        0
# 77413  4807451.0       12    2018        34    180.0        0        0
# 77414  4807452.0       12    2018        34      2.0        0        0
# 77415  4807515.0       11    2018        34     18.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3 FJDcode4 FJDcode5  FJDcode6 FJDcode7  \
# ...

# %%
unmatched_ussc_2 = (unmatched_2 >>
mask(unmatched_2.USSCIDN.notna()) >>
drop(unmatched_2.ID, unmatched_2.FJDcode1, unmatched_2.FJDcode2, unmatched_2.FJDcode3, unmatched_2.FJDcode4, unmatched_2.FJDcode5, unmatched_2.FJDcode5, unmatched_2.FJDcode6, unmatched_2.FJDcode7, unmatched_2.FJDcode8, unmatched_2.FJDcode9, unmatched_2.FJDcode10)
)
unmatched_ussc_2
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 4            4    2018        90      0.0        0        0  2460083.0
# 5            4    2018        90      0.0        0        0  2461003.0
# 6            4    2018        90      0.0        0        0  2460083.0
# 7            4    2018        90      0.0        0        0  2461003.0
# 8            4    2018        90      0.0        0        0  2460083.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 23416        9    2018        34      0.0        0        0  2489743.0
# 23423        7    2018        34      0.0        0        0  2476093.0
# 23427        7    2018        34     12.0        0        0  2476050.0
# 23431        4    2018        34      7.0        0        0  2458187.0
# 23433        2    2018        34      8.0        0        0  2447299.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
unmatched_ussc_2['PRISTOT'] = unmatched_ussc_2['floorSENTTOT']
unmatched_ussc_2
# Out:
#        SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT    USSCIDN  \
# 4            4    2018        90      0.0        0        0  2460083.0
# 5            4    2018        90      0.0        0        0  2461003.0
# 6            4    2018        90      0.0        0        0  2460083.0
# 7            4    2018        90      0.0        0        0  2461003.0
# 8            4    2018        90      0.0        0        0  2460083.0
# ...        ...     ...       ...      ...      ...      ...        ...
# 23416        9    2018        34      0.0        0        0  2489743.0
# 23423        7    2018        34      0.0        0        0  2476093.0
# 23427        7    2018        34     12.0        0        0  2476050.0
# 23431        4    2018        34      6.0        0        0  2458187.0
# 23433        2    2018        34      7.0        0        0  2447299.0
#
#        floorSENTTOT  roundSENTTOT  USSCcode1  USSCcode2  USSCcode3  USSCcode4  \
# ...

# %%
fjc_ussc_3 = pd.merge(unmatched_fjc_2, unmatched_ussc_2, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'])
fjc_ussc_3
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0     4385027.0        8    2018         8      6.0        0        0
# 1     4385994.0        8    2018         8      6.0        0        0
# 2     4385052.0        4    2018         8      1.0        0        0
# 3     4385447.0        4    2018         8      1.0        0        0
# 4     4391108.0        1    2018         9      6.0        0        0
# ...         ...      ...     ...       ...      ...      ...      ...
# 1620  4569019.0        2    2018        31      7.0        0        0
# 1621  4573815.0        2    2018        31      7.0        0        0
# 1622  4573815.0        2    2018        31      7.0        0        0
# 1623  4578809.0        4    2018        34      6.0        0        0
# 1624  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
dup_id_3 = fjc_ussc_3.loc[fjc_ussc_3.duplicated(subset='ID', keep='last')]
dup_idn_3 = fjc_ussc_3.loc[fjc_ussc_3.duplicated(subset='USSCIDN', keep='last')]
dup_3 = pd.concat([dup_id_3, dup_idn_3], axis=0)
dup_3
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 5     4394983.0        1    2018        13      9.0        0        0
# 7     4406543.0        4    2018        16      8.0        0        0
# 14    4417090.0        4    2018        22     12.0        0        0
# 16    4417228.0        4    2018        22     12.0        0        0
# 18    4417256.0        2    2018        22      0.0        0        0
# ...         ...      ...     ...       ...      ...      ...      ...
# 1613  4551229.0        7    2018        84      8.0        0        0
# 1619  4569019.0        2    2018        31      7.0        0        0
# 1620  4569019.0        2    2018        31      7.0        0        0
# 1621  4573815.0        2    2018        31      7.0        0        0
# 1623  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
fjc_ussc_3 = fjc_ussc_3.drop_duplicates(subset='ID', keep='first')
fjc_ussc_3 = fjc_ussc_3.drop_duplicates(subset='USSCIDN,', keep='first')
fjc_ussc_3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/shiramichel/Documents/JUSTFAIR/merge_match_2018.ipynb Cell 30' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/shiramichel/Documents/JUSTFAIR/merge_match_2018.ipynb#ch0000041?line=0'>1</a> fjc_ussc_3 = fjc_ussc_3.drop_duplicates(subset='ID', keep='first')
# ----> <a href='vscode-notebook-cell:/Users/shiramichel/Documents/JUSTFAIR/merge_match_2018.ipynb#ch0000041?line=1'>2</a> fjc_ussc_3 = fjc_ussc_3.drop_duplicates(subset='USSCIDN,', keep='first')
#       <a href='vscode-notebook-cell:/Users/shiramichel/Documents/JUSTFAIR/merge_match_2018.ipynb#ch0000041?line=2'>3</a> fjc_ussc_3
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
matched = []
no_match = []

for i in range(len(fjc_ussc_3)):
    for j in range(len(fjc_ussc_3)):
        if fjc_ussc_3.iloc[i,7] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,7] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,7] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,7] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,7] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,8] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,8] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,8] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,8] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,8] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,9] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,9] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,9] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,9] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,9] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,10] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,10] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,10] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,10] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,10] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,11] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,11] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,11] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,11] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,11] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,12] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,12] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,12] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,12] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,12] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,13] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,13] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,13] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,13] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,13] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,14] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,14] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,14] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,14] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,14] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,15] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,15] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,15] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,15] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,15] == fjc_ussc_3.iloc[j,24] or fjc_ussc_3.iloc[i,16] == fjc_ussc_3.iloc[j,20] or fjc_ussc_3.iloc[i,16] == fjc_ussc_3.iloc[j,21] or fjc_ussc_3.iloc[i,16] == fjc_ussc_3.iloc[j,22] or fjc_ussc_3.iloc[i,16] == fjc_ussc_3.iloc[j,23] or fjc_ussc_3.iloc[i,16] == fjc_ussc_3.iloc[j,24]:
           matched.append(i)
           break
        else:
            no_match.append(i)
            break

# %%
unmatched_3 = pd.merge(unmatched_fjc_2, unmatched_ussc_2, on=['SENTMON', 'SENTYR', 'DISTRICT', 'PRISTOT', 'FINETOT', 'PROBTOT'], how='outer')
unmatched_3
# Out:
#                ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 0       4365582.0        2    2018        90   9996.0        0        0
# 1       4365583.0        5    2018        90   9996.0        0        0
# 2       4365752.0        6    2018        90     86.0       36        0
# 3       4365799.0        2    2018        90    144.0        0        0
# 4       4366103.0        6    2018        90      0.0        0       60
# ...           ...      ...     ...       ...      ...      ...      ...
# 160148        NaN        7    2018        18     19.0     1000        0
# 160149        NaN        9    2018        44      0.0      350        0
# 160150        NaN        8    2018        91     82.0        0        0
# 160151        NaN        8    2018        91    240.0        0        0
# 160152        NaN        5    2018        10     70.0        0        0
#
#         FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_3 = fjc_ussc_3.iloc[matched,:]
matched_3.reset_index()

unmatched_3 = unmatched_3.append(fjc_ussc_3.iloc[no_match,:])
# Out:
# /var/folders/r7/bqljw8h17hsc6g3m8ck8vhjc0000gn/T/ipykernel_9411/3400029661.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unmatched_3 = unmatched_3.append(fjc_ussc_3.iloc[no_match,:])

# %%
matched_2018 = pd.concat([matched_1, matched_2, matched_3], axis=0)
matched_2018
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 3      4366344.0        7    2018        90     60.0        0        0
# 5      4366355.0        1    2018        90     18.0        0        0
# 7      4366380.0        1    2018        90    180.0        0        0
# 8      4366389.0        1    2018        90     78.0        0        0
# 10     4366406.0        4    2018        90     60.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23392  4578932.0        6    2018        34      0.0        0        0
# 23398  4579662.0        6    2018        34      0.0        0        0
# 23401  4578937.0        5    2018        34      0.0        0        0
# 2287   4535508.0        9    2018        78      0.0        0        0
# 2288   4535512.0        9    2018        78      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2018.drop_duplicates(subset=['USSCIDN', 'ID'])
matched_2018
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 3      4366344.0        7    2018        90     60.0        0        0
# 5      4366355.0        1    2018        90     18.0        0        0
# 7      4366380.0        1    2018        90    180.0        0        0
# 8      4366389.0        1    2018        90     78.0        0        0
# 10     4366406.0        4    2018        90     60.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23392  4578932.0        6    2018        34      0.0        0        0
# 23398  4579662.0        6    2018        34      0.0        0        0
# 23401  4578937.0        5    2018        34      0.0        0        0
# 2287   4535508.0        9    2018        78      0.0        0        0
# 2288   4535512.0        9    2018        78      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
matched_2018.to_csv('matched_2018.csv', index=False)

# %%
unmatched_2018 = pd.concat([dup, dup2, dup3, unmatched, unmatched_2, unmatched_3], axis=0)
unmatched_2018
# Out:
#              ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 1     4366322.0        7    2018        90     60.0        0        0
# 3     4366344.0        7    2018        90     60.0        0        0
# 8     4366389.0        1    2018        90     78.0        0        0
# 13    4366429.0        2    2018        90      0.0        0       36
# 15    4366620.0        2    2018        90      0.0        0       36
# ...         ...      ...     ...       ...      ...      ...      ...
# 2647  4554338.0        9    2018        87      6.0        0        0
# 2649  4561168.0        3    2018        29      4.0        0        0
# 2650  4569019.0        2    2018        31      7.0        0        0
# 2652  4573815.0        2    2018        31      7.0        0        0
# 2654  4578809.0        4    2018        34      6.0        0        0
#
#       FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...

# %%
unmatched_2018.to_csv('unmatched_2018.csv', index=False)

# %%
matched_2018.loc[matched_2018.duplicated(subset='USSCIDN', keep=False)]
# Out:
#               ID  SENTMON  SENTYR  DISTRICT  PRISTOT  FINETOT  PROBTOT  \
# 18     4366443.0        1    2018        90     70.0        0        0
# 19     4366444.0        1    2018        90     70.0        0        0
# 30     4366485.0        9    2018        90     60.0        0        0
# 32     4366684.0        9    2018        90     60.0        0        0
# 34     4366766.0        9    2018        90     60.0        0        0
# ...          ...      ...     ...       ...      ...      ...      ...
# 23282  4578514.0        5    2018        33      0.0        0        0
# 23392  4578932.0        6    2018        34      0.0        0        0
# 23398  4579662.0        6    2018        34      0.0        0        0
# 2287   4535508.0        9    2018        78      0.0        0        0
# 2288   4535512.0        9    2018        78      0.0        0        0
#
#        FJDcode1 FJDcode2 FJDcode3  ... FJDcode9 FJDcode10    USSCIDN  \
# ...
